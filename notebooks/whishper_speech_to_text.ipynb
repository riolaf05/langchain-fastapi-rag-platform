# %% [markdown]
# See https://towardsdatascience.com/speech-to-text-with-openais-whisper-53d5cea9005e

# %%
import whisper
import pytube
import progressbar

# %%
# model = whisper.load_model("large")
model = whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:25<00:00, 5.67MiB/s]

# %%
url = "https://www.youtube.com/watch?v=-LIIf7E-qFI"

# %%
def download_youtube_video(url):
    data = pytube.YouTube(url)
    # Converting and downloading as 'MP4' file
    audio = data.streams.get_audio_only()
    audio.download()

# %%
download_youtube_video(url)

# %%
text = model.transcribe(r"C:\Users\ELAFACRB1\Codice\GitHub\media-chat-service\src\embedding\experiments\test.mp4")

# %%
text['text']
# Out:
# " I Don't know who you are I Don't know what you want If you are looking for ransom, I can tell you I don't have money, but what I do have Are a very particular set of skills Skills I have acquired over a very long career skills to make me a nightmare for people like you If you let my daughter go now, that'll be the end of it. I Will not look for you. I will not pursue you but if you don't I Will look for you. I will find you And I will kill you Good luck"

# %% [markdown]
# Vedi anche https://github.com/alesaccoia/VoiceStreamAI per streaming

# %% [markdown]
# 54 min audio

# %%
result = model.transcribe(r'C:\Users\ELAFACRB1\Codice\GitHub\chatgpt-summmary\test\Asma_bagetta.m4a')
# Out:
# c:\Users\ELAFACRB1\venvs\langchain\Lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print(result['text'])
# Out:
#  non so che è la basma dice che è una malattia e progettiva quindi non è una sola malattia sono più un malattie è che normalmente è caracterizzata dalla situazione delle viee quindi noi guardiamo di varia di della basma con grupe dell'asma o attivituro guardiamo di class mi sono spregato o difenutivi per dire che l'asma si manifesta l'acquanto divista clinico sempre è un stesso modo ma dal punto di vista di psicotologico è completamente diversa la sma all'ergico da un asma in volta da meccanismi sono legolare oppure in volta da in pezionale oppure in volta da alti meccanismi quindi l'asma da volta divista della scuola nella gestorzione delle effe fenomenologie cliniche si non è questa sbagliore stesso modo però noi dobbiamo capire il freno tipo oppure sei altruo il freno tipo è sotteso una pagogenza specifica un'otale che si individua di mentale e guarda in manipolare per su cui il riso di fare che cosa è un asma da condo di stade scintamente è la presenza di un respiro semplice una 
# ...

# %% [markdown]
# # Whishper vs Transcribe

# %%
import whisper
import sys
sys.path.append('..')
from utils import AWSTexttract, TextSplitter, LangChainAI
import progressbar

# %%
model = whisper.load_model("base")

# %%
filename=r"C:\Users\ELAFACRB1\Downloads\AUD-20240319-WA0006.m4a"
text = model.transcribe(filename)
# Out:
# c:\Users\ELAFACRB1\venvs\langchain\Lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
text['text']
# Out:
# " Ciao ragazzi buongiorno. Buongiorno a tutti. Si sente bene, però anche dietro si sente. Allora ragazzi un paio di avvisimo, nevo farvi. Per quanto riguarda il mese di marzo di affile, troverete quando pubblica in un paio di appuntamenti in più, di approfondimenti, oltre le canoniche, lezioni che pensate. E saranno due approfondimenti due focos, uno di penale e uno in materia di civile. Uno sarà registrato, quindi veloca richeremo nei cruxcotti e rimarrà vostra disposizione da parte della proessore ssamorello. E poi l'altro invece sarà indiretta un paio di ore su piattaforma zoom con l'avvocato del lo stato in manu e le manzo. Invece per quanto riguarda l'altra novità è che da questo l'unedice, da l'unedì prossimo, torna l'appuntamento ogni l'unedì diciamo di fine mese. Per gli approfondimenti con il presidente, sempre su piattaforma zoom ovviamente, gli approfondimenti su tutte le questioni di rilievo ovviamente che avete trattato nel mese appena concluso. Quindi magari il presiden
# ...

# %% [markdown]
# Summarize

# %%
langchain_client = LangChainAI()
text_summarizer = TextSplitter(chunk_size=16000, chunk_overlap=0)
# Out:
# c:\Users\ELAFACRB1\venvs\langchain\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
splitted_text = text_summarizer.semantic_split_text(text['text'])

# %%
splitted_text
# Out:
# ['Per quanto riguarda il mese di marzo di affile, troverete quando pubblica in un paio di appuntamenti in più, di approfondimenti, oltre le canoniche, lezioni che pensate. E saranno due approfondimenti due focos, uno di penale e uno in materia di civile.',
# ...

# %%
docs =  text_summarizer.create_langchain_documents(splitted_text, {"source": "mp3"})
len(docs)
# Out:
# 33

# %%
docs[32]
# Out:
# Document(page_content="Tutte le norme che abbiamo ricordato prima, 1.326 procedimenti agravati, procedimenti leggeri, procedimenti riferenziate, sono norme, le quali e simplificano. Alcune modalità di formazione erzite in un te lo più frequenti, le più ricorrendi, quelle socialmente tipiche, quindi legalmente tipizzate. Niente questa norma, limitando e se non norme sempre le vicative, la possibilità di stimolare contratti, intrebbero il procedimento di ricare attra, riferso. Ed altro onno, e onno, voglio dire, giorgio a chiara e tutte le altre, le norme, il principio di autonomia in eccozziale, 1.322 è un principio che riguarda non solo il contenuto, ma anche la modalità di formazione, il contatto. Non c'è alcune ragione di ordine pubblico che i tu stivi, che una disu... Autovetetiva del mondo di arrivare a contatto, i città filiali alla possibilità per le parti di plasma del... ...e te diverse, una delle tipizzate, come hanno detto le istizioni unitte e una sentenza per l'altro, è u
# ...

# %%
#entire text
docs =  text_summarizer.create_langchain_documents(text['text'], {"source": "mp3"})
len(docs)
# Out:
# 1

# %%
##clear text
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain, SimpleSequentialChain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(
        model_name="gpt-3.5-turbo-16k", # default model
        temperature=0.9
        )

# %%
# Define prompt
prompt_template = """
Riscrivi l'intero testo fornito, mantenendo la lunghezza originale e cambiando solo le frasi 
incomprensibili per ottenre un testo chiaro:
"{text}"
Resto comprensibile:"""
prompt = PromptTemplate.from_template(prompt_template)

# Define LLM chain
llm_chain = LLMChain(
    llm=llm, 
    prompt=prompt
)

# %%
# # Define StuffDocumentsChain
# stuff_chain = StuffDocumentsChain(
#     llm_chain=llm_chain, 
#     document_variable_name="text",
# )

# %%
final=""
for doc in docs:
    result=llm_chain.run(doc)
    print(result)
    final=final+result+'/n'
# Out:
# "Per quanto riguarda il mese di marzo, troverete una serie di appuntamenti in più rispetto al solito, oltre alle canoniche lezioni che conoscete. E saranno due approfondimenti molto interessanti, uno riguardante il diritto penale e l'altro riguardante il diritto civile."
# ...

# %%
final.replace("metadata={'source': 'mp3'}", "")
# Out:
# '"Per quanto riguarda il mese di marzo, troverete una serie di appuntamenti in più rispetto al solito, oltre alle canoniche lezioni che conoscete. E saranno due approfondimenti molto interessanti, uno riguardante il diritto penale e l\'altro riguardante il diritto civile."/n"Uno dei due sarà registrato, quindi velocemente richiameremo i partecipanti e rimarrà a disposizione del professore Ssamorello. L\'altro, invece, avrà un incontro indiretto di un paio di ore su piattaforma zoom con l\'avvocato dello stato in questione. Inoltre, una nuova novità è che a partire da questo mese, l\'appuntamento ogni fine mese sarà ripristinato a partire dal prossimo lunedì. Per quanto riguarda gli approfondimenti con il presidente, sempre su piattaforma zoom ovviamente, si tratteranno tutte le questioni di rilievo che sono state discusse il mese appena concluso. Quindi, probabilmente il presidente vi farà delle domande in anticipo sul gruppo Facebook, su cui potremmo scegliere gli argomenti e soprat
# ...

# %%
final_splitted_text = text_summarizer.semantic_split_text(final)
final_docs =  text_summarizer.create_langchain_documents(final_splitted_text, {"source": "mp3"})
len(final_docs)
# Out:
# 38

# %%
final_docs
# Out:
# [Document(page_content='"Per quanto riguarda il mese di marzo, troverete una serie di appuntamenti in più rispetto al solito, oltre alle canoniche lezioni che conoscete. E saranno due approfondimenti molto interessanti, uno riguardante il diritto penale e l\'altro riguardante il diritto civile. "/n"Uno dei due sarà registrato, quindi velocemente richiameremo i partecipanti e rimarrà a disposizione del professore Ssamorello. L\'altro, invece, avrà un incontro indiretto di un paio di ore su piattaforma zoom con l\'avvocato dello stato in questione. Inoltre, una nuova novità è che a partire da questo mese, l\'appuntamento ogni fine mese sarà ripristinato a partire dal prossimo lunedì. Per quanto riguarda gli approfondimenti con il presidente, sempre su piattaforma zoom ovviamente, si tratteranno tutte le questioni di rilievo che sono state discusse il mese appena concluso. Quindi, probabilmente il presidente vi farà delle domande in anticipo sul gruppo Facebook, su cui potremmo sceglier
# ...

# %%
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate

# Define prompt
prompt_template = """Scrivi un riassunto del seguente testo::
"{text}"
Riassunto Conciso:"""
prompt = PromptTemplate.from_template(prompt_template)

# Define LLM chain
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-16k")
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Define StuffDocumentsChain
stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")

print(stuff_chain.run(final_docs))
# Out:
# Il testo riguarda una serie di appuntamenti e approfondimenti riguardanti il diritto penale e civile che si terranno nel mese di marzo. Uno degli approfondimenti sarà registrato e rimarrà a disposizione del professore, mentre l'altro avrà un incontro su piattaforma zoom con un avvocato. Inoltre, si ripristinerà l'appuntamento mensile con il presidente su piattaforma zoom per discutere le questioni rilevanti del mese precedente. Si invita a porre domande sul gruppo Facebook per prepararsi agli argomenti. Si sottolinea l'importanza di approfondire gli argomenti anziché limitarsi agli appunti. Si parlerà anche della responsabilità contrattuale e della lettera di patronage. Si discute anche della possibilità di modificare i contratti in base al principio della buona fede. Si affrontano anche le obiezioni a questa idea e si sottolinea l'importanza della certezza, dell'autonomia e del numero chiuso delle cause di invalidità. Si discute anche della responsabilità precontrattuale e dei vizi 
# ...

# %% [markdown]
# Map Reduce

# %%
from langchain.chains import MapReduceDocumentsChain, ReduceDocumentsChain
# from langchain_text_splitters import CharacterTextSplitter

llm = ChatOpenAI(temperature=0)

# Map
map_template = """Di seguito un testo lungo diviso in documenti:
{docs}
Basansoti su questa lista di documenti, per favore crea un riassunto per ciascuno di essi. 
Riassunto:"""
map_prompt = PromptTemplate.from_template(map_template)
map_chain = LLMChain(llm=llm, prompt=map_prompt)

# %%
# Reduce
reduce_template = """Di seguito una lista di riassunti:
{docs}
Prendi queste informazioni e sintetizzale in un elenco puntato finale che contiene i temi principali trattati.. 
Risposta:"""
reduce_prompt = PromptTemplate.from_template(reduce_template)

# Run chain
reduce_chain = LLMChain(llm=llm, prompt=reduce_prompt)

# %%
# Takes a list of documents, combines them into a single string, and passes this to an LLMChain
combine_documents_chain = StuffDocumentsChain(
    llm_chain=reduce_chain, document_variable_name="docs"
)

# %%
# Combines and iteratively reduces the mapped documents
reduce_documents_chain = ReduceDocumentsChain(
    # This is final chain that is called.
    combine_documents_chain=combine_documents_chain,
    # If documents exceed context for `StuffDocumentsChain`
    collapse_documents_chain=combine_documents_chain,
    # The maximum number of tokens to group documents into.
    token_max=4000,
)

# %%
# Combining documents by mapping a chain over them, then combining results
map_reduce_chain = MapReduceDocumentsChain(
    # Map chain
    llm_chain=map_chain,
    # Reduce chain
    reduce_documents_chain=reduce_documents_chain,
    # The variable name in the llm_chain to put the documents in
    document_variable_name="docs",
    # Return the results of the map steps in the output
    return_intermediate_steps=False,
)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=0)
split_docs = text_splitter.split_documents(final_docs)

# %%
print(map_reduce_chain.run(split_docs))
# Out:
# - Approfondimenti sul diritto penale e civile
# - Responsabilità contrattuale e precontrattuale
# - Trattative finanziarie e lettera di patronage
# - Prospetti bancari fuorvianti
# - Cessione del credito e responsabilità degli operatori economici
# - Vizi nella vendita, locazione e comodato
# - Legge del 1604 sull'obbligazione
# - Buona fede e articolo 1337
# - Autonomia negoziale e interferenze
# - Correzione del contenuto economico del contratto
# - Restituzioni e danno precontrattuale
# - Aromanticismo nel codice civile
# - Obblighi contrattuali e regole di comportamento
# - Formazione del contratto e modalità specifiche
# - Limiti alle norme contrattuali
# - Principio di autonomia
# - Importanza dell'accordo tra le parti
# - Risoluzione delle situazioni conflittuali
# - Eliminazione dell'autonomia contrattuale
# - Dubbio sull'interesse pubblico

# %% [markdown]
# # Usando Transcribe

# %%
from utils import AWSTranscribe, AWSS3
from dotenv import load_dotenv
load_dotenv(override=True)
import os
S3_BUCKET=os.getenv('S3_BUCKET')
JOB_URI=os.getenv('JOB_URI')
s3client = AWSS3(S3_BUCKET)
transcribe = AWSTranscribe(JOB_URI)
import logging
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate

folder=r"C:\Users\ELAFACRB1\Downloads"
filename=r"AUD-20240319-WA0006.m4a"

def speech_to_text(job_name, language_code):
    job_name=transcribe.generate_job_name()
    data = transcribe.amazon_transcribe(JOB_URI, job_name, filename, language_code)
    logging.info("File audio transcribed!")
    return data

# %%
# s3client.upload_file(os.path.join(folder, filename),filename)

# %%
# trascribe_text = speech_to_text(filename, 'it-IT')

# %%
# trascribe_text
# Out:
# "Ciao ragazzi. Buongiorno a parte della coppia. Buongiorno a tutti! A strana si sente bene, vero? Anche dietro si sente giusto. Allora, ragazzi, un paio di eh di avvisi volevo farvi. Allora, per quanto riguarda il mese di marzo di aprile, troverete quando pubblicheremo il calendario, un paio di appuntamenti in più di approfondimenti oltre le canoniche elezioni che ben sapete e saranno due approfondimenti, due focus, uno di penale e uno in materia di civile. Uno
ed è da parte vostra doveroso è necessario non mancare a nessuna lezione. Io confido che chi non viene in sede fisica per impedimenti oggettivi che d'ora in poi andranno documentati, diciamo con apposita certificazione medica presso L'avvocato Marzano. Poi recuperi la lezione perché il programma è unitario e tutti gli elementi del programma vanno visti, diciamo insieme. Allora la lezione di oggi è dedicata alla formazione del contratto dopo che le prime due lezioni sul contratto le abbiamo dedicate alla nozione di contratto, soffermandoci soprattutto sulla causa e sulla meritevolezza alla patologia del contratto, soffermandoci soprattutto sulla sulle nullità. Oggi invece la formazione prima ci occuperemo della formazione come comportamento, quindi un comportamento che va tenuto dalle parti nel corso della formazione del contratto. Comportamento di che deve essere informato a canoni di correttezza, buona fede e dirigenza, pena la configurazione della responsabilità precontrattuali poi Anita ci occuperemo della formazione come procedimento, quindi il procedimento, la serie di atti giuridici che conducono alla conclusione del contratto ed esamineremo il procedimento ordinario, i procedimenti differenziati e il procedimento di formazione aggressiva con Sua Maestà il contratto preliminare e sulla responsabilità precontrattuale. Ho pubblicato un post che ho capito benissimo, che non vi ha fatto né caldo né freddo, ma è essenziale al post perché credo e spero di avere sintetizzato i concetti più rilevanti. La responsabilità precontrattuale è una responsabilità che ha come paradigma generale gli articoli milletrecentotrentasette e millecentotrentotto C C. Ma ha come paradigmi speciali delle normative speciali che prevedono obblighi comportamentali nel corso del procedimento di formazione del contratto. Quindi le normative speciali in materia di consumatori in materia di pubblica amministrazione, in materia di contratti bancari, di contratti assicurativi, di contratti finanziari. Il filo conduttore di questa riflessione iniziale nella prima parte della lezione sarà l'espansione della responsabilità precontrattuale, perché la responsabilità precontrattuale è passata domiziana nel corso degli ultimi anni, da un modello basato sulla tipizzazione, cioè la responsabilità precontrattuale in presenza di determinati comportamenti tipizzati dalla legge millecentotrentotto o tipizzati dalla giurisprudenza. Passaggio da un modello tipizzate a un modello atipico basato sulla clausola generale sulla norma general, per cui le responsabilità precontrattuale non sono, nei casi tipizzati di scorrettezza nei casi di scorrettezza tipizzati dalla legge o dalla giurisprudenza che integra la legge, ma in tutte le ipotesi in cui vi sia un comportamento scorretto, produttivo ed un danno. Una lettura atipica che fa del tutto il paio con il carattere di clausola generale della buona fede che il canone che deve informare il comportamento precontrattuale. Questa atipicità ha diverse variabili e enunciamo rapidamente la prima e più importante atipicità e il superamento dell'idea che la responsabilità precontrattuale debba essere collegata alla trattativa fallita, alla trattativa fallita, cioè la trattativa che non culmina in modo positivo nel risultato atteso, cioè nella stipulazione di un contratto valido ed efficace. È fallita sia la trattativa quando il contratto non c'è il recesso ingiustificato dalle trattative, sia quando il contratto c'è, ma è come se non ci fosse perché è inefficace. Nulla improduttivo di effetti viene successivamente caducato questa tradizionale conformazione della responsabilità precontrattuale da trattativa fallita, in cui il bene giuridico leso e l'affidamento nella futura stipulazione del contratto si accompagna invece una responsabilità precontrattuale dal comportamento scorretto che produce un comportamento, o meglio che produce un contratto valido ma ingiusto, valido ma dannoso. Valido ma pregiudiziale. Quindi ipotesi in cui la trattativa non è fallita perché si è arrivati ad un contratto valido. Ma la trattativa è stata connot
o contrattuale, ma senza contratto lo trovo meraviglioso. Vallo a spiegare in Svezia contrattuale, ma il contratto ci dice Ma poi chi cazzo la chiami contrattuale così contrattuale ma non ex? Beh, diciamo senza volere più indugiare su tutte le criticità che abbiamo esposto nella prima lezione, quando avevamo tutti venticinque anni in meno. Le critiche verso il contatto sociale. Qui obiettivamente più che una critica, emerge una perplessità sulla necessità di richiamare il contatto sociale nell'ipotesi nella responsabilità precontrattuali infatti la responsabilità contrattuale da contatto sociale per violazione diciamo, della clausola generale della buona fede dei contatti sociali atipici ha senso quando la legge non specifichi con una norma apposita che c'è l'esistenza di un rapporto obbligatorio, cioè se c'è una norma come il milletrecentotrentasette, che modo puntuale giuridici una relazione sociale generica e la trasforma in rapporto obbligatorio in senso tecnico. Che bisogno c'è devi chiamare il contatto su ciò. Più che parlare di responsabilità da contatto sociale, che è una figura atipica a cui c'è bisogno di ricorrere, se non c'è una previsione legale, sarebbe più logico e sarebbe meno diciamo complicato parlare invece di una responsabilità contrattuale per inadempimento di un obbligo ex legge responsabilità contrattuale per inadempimento di un obbligo previsto puntualmente dalla legge e l'articolo milletrecentotrentasette che contrattualizza. Questo è un rapporto che lo trasforma da mero momento della vita di relazione generica in vera e propria forma di rapporto obbligatorio. Ed è quello che dice con molta chiarezza Mengoni, forse il giurista più puro dal punto di vista della sistematica e della dogmatica che, come ribadisco nel post ci ricorda che quando una norma giuridica assoggetta la relazione sociale all'imperativo della buona fede, trasforma questa relazione sociale in rapporto obbligatorio e quindi contrattualizza la relativa responsabilità. Quindi diciamo, um parlare di responsabilità contrattuale da contatto sociale per portare acqua al mulino di una teorica dalla dubbia, diciamo solidità è inutile, perché quando c'è una legge precisa che giuridici con la buona fede questa relazione è più logico parlare di responsabilità contrattuale da inadempimento di un obbligo previsto espressamente dalla legge. In ogni caso, di fronte a questa responsabilità precontrattuale senza contratto, e lo abbiamo ribadito nel posto e si pone il problema l'applicabilità di norme che il codice civile ha previsto immaginando la responsabilità contrattuale da contratto, qui invece abbiamo una responsabilità contrattuale senza contratto. Qual è la differenza? È che nel contratto le prestazioni sono determinate in modo puntuale e quindi sono prevedibili gli inadempimenti e soprattutto i pregiudizi. Invece nella responsabilità contrattuale senza contratto in cui l'obbligo violato non è un obbligo preciso previsto nel contratto, ma l'obbligo generale di buona fede. I comportamenti in adempitivi non sono tipizzati e i danni quindi non sono prevedibili. Per questo c'è il problema dell'applicabilità alla responsabilità contrattuale senza contratto del milleduecento diciotto, che esonera il debitore dalla prova dell'inadempimento sulla base dell'assunto che il comportamento del debitore è la causa più probabile dell'inadempimento e milleduecentoventicinque che limita il risarcimento al danno prevedibile se non c'è do c'è la base dell'assunto che al momento del contratto c'è una chiara programmazione e quindi possibilità di previsione. Queste due norme, secondo Giovanni Grasso, postulano entrambe la predeterminazione puntuale del contenuto dell'obbligazione e non sono quindi estensibili ad una responsabilità precontrattuale da violazione di una clausola generale e non da violazione di un obbligo comportamentale preciso. Ma quello che ci interessa di più torno Francesca alla domanda principale è la problematica della responsabilità precontrattuali da contratto valido ma
dell'atto finisce per essere una violazione di regola sull'atto. In ultima analisi, a questa prima obiezione se ne accompagna una seconda è che e più propriamente diciamo, legata alla coerenza sistematica. E si dice questo meccanismo di correzione del contenuto economico di un contratto valido finisce per essere profondamente contraddittorio, perché tu da un lato conosci che il contatto è valido dall'altro lato però in ultima analisi lo svuoti del suo contenuto e quindi c'è una profonda incoerenza in questa sorta di effetto anomalo che è ghigliottinare un contratto. Per quanto tu lo consideri valido ed efficace, è contraddittorio affermare che è efficace. E poi, in ultima analisi, incidere sugli effetti del contratto è è la cosiddetta teoria dell'immunità. Se il contratto è valido vuol dire che è un contratto efficace validità ed efficacia. Parli insieme contratto valido è un contratto efficace, un contratto efficace vuol dire che è immune rispetto a rimedi restituto. Qui invece, attraverso questo risarcimento del danno tu costringi la parte avvantaggiata a restituire il vantaggio che hai ottenuto. La parte svantaggiata consente a questo di ottenere la diciamo la restituzione. Quindi, diciamo questa è la seconda obiezione. Simone ci aspettavamo. La terza obiezione è la violazione dell'analogia e in ultima analisi si estendono analogicamente a quelle norme eccezionali che prevedono la riscrittura economica e quindi il depotenziamento degli effetti del contratto valido. Pensiamo al milleottocentoquaranta. Il loro incidente è un caso eccezionale in cui pur essendo valido il contratto c'è un risarcimento del danno da responsabilità precontrattuale, ma anche tutte le norme sui vizi millequattrocentonovanta i vizi nella vendita millecinquecento settantotto i vizi nella locazione milleottocentododici i vizi nel comodato milleottocentoventuno mi sono dimenticato le poste, scrivetelo i vizi, eh? Nel mutuo e in tutti questi casi la legge, eccezionalmente attraverso la disciplina dei vizi e la possibilità di riduzione del prezzo, incide sugli effetti economici del contratto valido. Ma sono norme eccezionali che dimostrano le esistenze mille e sei e quattro sulla palma. Sono casi eccezionali che dimostrano che la regola è quella opposta. E poi, infine, l'ultima obiezione è che si attribuisce una anomala rilevanza all'errore sui motivi perché in definitiva, se stipula un contratto sulla base di un'erronea prefigurazione degli dei vantaggi che dal contratto avrei ottenuto io ho stipulato sulla base di un errore sui motivi e l'errore sui motivi è un errore generalmente privo di rilevanza giuridica, che qui viene invece tenuto anomalo, recuperato. Diciamo quindi queste le obiezioni, ma si limitano essenzialmente alla prima. È una tesi quella del danno precontrattuale da contratto valido, che destabilizza la certezza dei rapporti giuridici destabilizza l'autonomia negoziale destabilizza il principio di non interferenza tra regole di condotta e regole sull'atto destabilizza il principio del numero chiuso dei vizi della volontà e delle cause di invalidità. È una soluzione del tutto incoerente perché pretende di destabilizzare gli effetti di un contratto dopo aver affermato che è valido ed efficace. Ma se il contratto è valido, quindi efficace vuol dire che è immune dai rimedi ai restituto che non possono essere, attraverso le restituzioni destabilizzati gli effetti prodotti dal contratto valido. Estende analogicamente alle ipotesi eccezionali di diciamo riequilibrio nei contratti validi e attribuisce una rilevanza anomala all'errore sui motivi e vi devo dire che queste critiche sono di retroguardia e sono obiettivamente di un'a antichità insopportabile. Pur essendo comprensibili dal punto di vista della linea teorica queste critiche io e quindi voi in piena diciamo so giacenza e rispondiamo tutti negativamente in primo luogo sul piano lettera perché l'articolo milletrecentotrentas
, il reato di truffa, il reato di insolvenza fraudolenta, il reato di diciamo espulsione beh, è chiaro che la rilevanza penale è la condotta è un indice della significatività dell'interferenza. Altro caso sezioni unite duemila sette. E quando la condotta ha violato un preciso obbligo di informazione previsto dalla legge, quando c'è la legge stessa selezione nel mucchio dei comportamenti, dei comportamenti particolarmente rilevanti e vi impone gli obblighi di informazione a carico degli intermediari finanziari. Ventitré del testo unico in combinazione con l'articolo ventuno del testo unico. Cinquantotto del novantotto, per non dire gli obblighi di informazione a favore del consumatore. Previsti molti contratti consumistici, come i contratti a distanza, come la multiproprietà, come i contratti relativi al turistico. Bene, quindi io credo che queste obiezioni possano essere superate. Quindi, ricapitolando, alla tesi della Cassazione della risarcibilità del danno precontrattuale da contratto valido ma sconveniente come reazione al contratto squilibrato, frutto di comportamento scorretto in un contesto asimmetrico caratterizzato da vizi incompleti della volontà, queste accuse si destabilizza. La certezza si crea un'invalidità atipica, si crea un vizio della volontà atipico. Si mette nel nulla il principio di non interferenza. Si consente un sindacato generalizzato sull'equilibrio contrattuale si scardina la coerenza del sistema. Si estendono analogicamente i casi tassativi in cui i contratti efficaci possono essere incisi sul piano degli effetti prodotti e si attribuisce una rilevanza anomala. All'errore sui motivi e a queste obiezioni sul piano milletrecentotrentasette è tipico sul piano astrologico. La buona fede è una clausola generale sul piano teologico. Lo scopo di protezione della norma vale anche per le condotte sleali che producono contratti ingiusti, non solo per le condotte superficiali che evitano la stipulazione del contratto finale, ma soprattutto sul piano sistematico. È importante ricordare questo non c'è una invalidità atipica, non c'è uno strumento atipico di correzione del contratto. Perché ci sarebbe invalidità atipica o strumento atipico di correzione del contratto se il giudice agisse sulla base della mera violazione di un precetto di giustizia obiettiva del contratto. Quindi accordarsi un danno per il solo fatto che il contratto è oggettivamente ingiusto, allora sarebbe certamente un'invalidità chiamata al risarcimento, perché andrebbe l' il risarcimento a reagire alla mera difformità del contratto rispetto a un paradigma di giustizia. Qui invece, ad essere violata è una regola comportamentale, tanto è vero che c'è bisogno che il comportamento sia colpevole, c'è bisogno che il comportamento sia dannoso e soprattutto c'è bisogno che il comportamento si inserisca all'interno di una trattativa asimmetrica. Sì da determinare una ingiustizia di carattere procedurale. Una Il rischio di accesso di tutela viene ad essere fronteggiato attraverso questo criterio di selezione della rilevanza, della alterazione della libertà negoziale, che deve essere una rilevanza significativa. A questo punto, diciamo, direi che la soluzione della Cassazione va salutata con favore, perché riprende la teoria dei vizi incompleti, nuovi, impropri, atipici della vizzi giri e chiarendo che millequattrocentoquaranta non è una norma eccezionale, ma è l'espressione di un principio per cui i vizi tipici producono invalidità, i vizi tipici tutti e il loro in incidente è solo un esempio. Producono un risarcimento del danno senza negare in modo radicale gli effetti contrattuali. Ora so che voi siete amanti di Rodolfo Sacco, soprattutto te, Sara. Quindi permettimi di ricordarti le parole di Rodolfo Sacco che con cui chiudo al primo post che dice c'è un rimedio del codice civile che potrebbe eliminare tutte le norme sull'errore sulla violenza e sul dolo senza modificare il contenuto di protezione del contraente che si trova a disagio a disagio. Questo è l'articolo milletrec
arazione, ma c'è semplicemente una attuazione della volontà della teoria di Santoro Passarelli per il milletrecentoventisette sarebbe come la distruzione del testamento olografo e cioè sarebbe una volontà meramente attuata la volontà che viene immediatamente realizzata, che esaurisce il suo intento con il comportamento senza essere destinata. Ricevuta resa percepibile, così come non è accettabile la lettura del milletrecentotrentatré come contratto senza accordo, quindi come contratto a struttura unilaterale, pur se ha effetti bilaterali, ci vediamo a fra quindici minuti, anzi tra diciotto A e dieci precise."

# %%
transcribe_splitted_text = text_summarizer.semantic_split_text(trascribe_text)
len(transcribe_splitted_text)
# Out:
# 67

# %%
#entire text
transcribe_docs =  text_summarizer.create_langchain_documents(transcribe_splitted_text, {"source": "mp3"})
len(transcribe_docs)
# Out:
# 67

# %%
transcribe_docs[0]
# Out:
# Document(page_content="Allora, ragazzi, un paio di eh di avvisi volevo farvi. Allora, per quanto riguarda il mese di marzo di aprile, troverete quando pubblicheremo il calendario, un paio di appuntamenti in più di approfondimenti oltre le canoniche elezioni che ben sapete e saranno due approfondimenti, due focus, uno di penale e uno in materia di civile. Uno sarà registrato, quindi ve lo caricheremo nei cruscotti e rimarrà a vostra disposizione da parte della professoressa Morello e poi l'altro invece sarà in diretta un paio di ore su piattaforma zoom con l'avvocato dello stato. Emanuele manzo, invece, per quanto riguarda l'altra novità, è che da questo lunedì, cioè da lunedì prossimo, torna l'appuntamento ogni lunedì, diciamo di fine mese e per gli approfondimenti con il presidente sempre su piattaforma Zoom, ovviamente. E gli approfondimenti su tutte le questioni di rilievo, ovviamente, che avete trattato nel mese appena concluso. Quindi magari il presidente stesso vi porrà delle d
# ...

# %%
##clear text
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain, SimpleSequentialChain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(
        model_name="gpt-3.5-turbo-16k", # default model
        temperature=0.9
        )

# %%
def clean_text(docs):

    #FIXME 
    bar = progressbar.ProgressBar(maxval=20, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
    i=0

    # Define prompt
    prompt_template = """
    Riporta il testo fornito uguale al testo di input.
    Modifica solo le frasi incomprensibili in modo da dare un senso logico al testo, ma facendo meno modifiche possibili. 

    Il testo in input: 
    "{text}"

    Il test di output:
    """
    prompt = PromptTemplate.from_template(prompt_template)

    # Define LLM chain
    llm_chain = LLMChain(
        llm=llm, 
        prompt=prompt
    )

    final=""
    bar.start()
    for doc in docs:
        doc=doc.page_content
        result=llm_chain.run(doc)
        final=final+result+'/n'
        bar.update(i+1)

    bar.finish()
    return final

# %%
transcribe_clean_text = clean_text(transcribe_docs)
# Out:
# [========================================================================] 100%

# %%
transcribe_clean_text
# Out:
# 'Allora, ragazzi, volevo darvi un paio di avvisi. Per quanto riguarda il mese di marzo e aprile, quando pubblicheremo il calendario, troverete alcuni appuntamenti extra oltre alle elezioni canoniche che già conoscete. Saranno due approfondimenti, uno sul diritto penale e uno sul diritto civile. Uno sarà registrato e lo caricheremo nei cruscotti per voi, a disposizione della professoressa Morello. L\'altro invece sarà in diretta su piattaforma Zoom per un paio d\'ore con l\'avvocato dello stato, Emanuele Manzo. Inoltre, dal prossimo lunedì, tornerà l\'appuntamento settimanale, verso la fine del mese, con il presidente sempre su piattaforma Zoom. Affronteremo tutte le questioni importanti che avete trattato nel mese appena concluso. Il presidente potrebbe fare delle domande anticipatamente nel gruppo Facebook, così potete riflettere in anticipo. Inoltre, consiglio di fare anche voi domande sempre su Facebook, così il presidente saprà già su quali argomenti concentrarsi e voi potrete sa
# ...

# %%
def summarize_text(docs):
        '''
        Takes docs in input, produce a text in output

        The map reduce documents chain first applies an LLM chain to each document individually (the Map step), 
        treating the chain output as a new document. 
        It then passes all the new documents to a separate combine documents chain to get a single output (the Reduce step). 
        It can optionally first compress, or collapse, 
        the mapped documents to make sure that they fit in the combine documents chain 
        (which will often pass them to an LLM). This compression step is performed recursively if necessary.
        '''

        llm = ChatOpenAI(temperature=0)

        #map
        map_template = """Di seguito un testo lungo diviso in documenti:
        {docs}
        Basansoti su questa lista di documenti, per favore crea un riassunto per ciascuno di essi. 
        Riassunto:"""
        map_prompt = PromptTemplate.from_template(map_template)
        map_chain = LLMChain(llm=llm, prompt=map_prompt)
        
        # Reduce
        reduce_template = """Di seguito una lista di riassunti:
        {docs}
        Prendi queste informazioni e sintetizzale in un riassunto finale e consolidato dei temi principali.
        Risposta:"""
        reduce_prompt = PromptTemplate.from_template(reduce_template)
        reduce_chain = LLMChain(llm=llm, prompt=reduce_prompt)
        
        # Combines and iteratively reduces the mapped documents
        combine_documents_chain = StuffDocumentsChain(llm_chain=reduce_chain, document_variable_name="docs")
        reduce_documents_chain = ReduceDocumentsChain(
            # This is final chain that is called.
            combine_documents_chain=combine_documents_chain,
            # If documents exceed context for `StuffDocumentsChain`
            collapse_documents_chain=combine_documents_chain,
            # The maximum number of tokens to group documents into.
            token_max=4000,
        )

        # Combining documents by mapping a chain over them, then combining results
        map_reduce_chain = MapReduceDocumentsChain(
            # Map chain
            llm_chain=map_chain,
            # Reduce chain
            reduce_documents_chain=reduce_documents_chain,
            # The variable name in the llm_chain to put the documents in
            document_variable_name="docs",
            # Return the results of the map steps in the output
            return_intermediate_steps=False,
        )

        return map_reduce_chain.run(docs)

# %%
transcribe_clean_docs=text_summarizer.semantic_split_text(transcribe_clean_text)

# %%
transcribe_clean_splitted_docs =  text_summarizer.create_langchain_documents(transcribe_clean_docs, {"source": "mp3"})
len(transcribe_clean_splitted_docs)
# Out:
# 40

# %%
transcribe_summarized_text=summarize_text(transcribe_clean_splitted_docs)

# %%
transcribe_summarized_text
# Out:
# "Il riassunto finale dei temi principali riguarda la formazione e l'esecuzione dei contratti, con particolare attenzione alla protezione dei soggetti fragili e alla tutela equilibrata in caso di comportamenti scorretti. Si discute della differenza tra annullamento e nullità nei contratti, del risarcimento del danno come strumento di protezione per i vizi atipici e della necessità di rispettare le regole e essere flessibili durante le procedure contrattuali. Viene sottolineata l'importanza del rispetto dell'autonomia privata nella creazione di modelli non convenzionali per la stipula di un contratto e della comunicazione completa e onesta nelle transazioni immobiliari. Infine, si analizzano i diversi modelli semplificati di contratti leggeri proposti e si riflette su quale principio possa essere ricavato da essi. Si parla anche delle norme che regolano la formazione dei contratti, sottolineando il principio di autonomia contrattuale e la possibilità per le parti di decidere liberament
ia del contratto, soffermandoci soprattutto sulla sulle nullità. Oggi invece la formazione prima ci occuperemo della formazione come comportamento, quindi un comportamento che va tenuto dalle parti nel corso della formazione del contratto. Comportamento di che deve essere informato a canoni di correttezza, buona fede e dirigenza, pena la configurazione della responsabilità precontrattuali poi Anita ci occuperemo della formazione come procedimento, quindi il procedimento, la serie di atti giuridici che conducono alla conclusione del contratto ed esamineremo il procedimento ordinario, i procedimenti differenziati e il procedimento di formazione aggressiva con Sua Maestà il contratto preliminare e sulla responsabilità precontrattuale. Ho pubblicato un post che ho capito benissimo, che non vi ha fatto né caldo né freddo, ma è essenziale al post perché credo e spero di avere sintetizzato i concetti più rilevanti. La responsabilità precontrattuale è una responsabilità che ha come paradigma generale gli articoli milletrecentotrentasette e millecentotrentotto C C. Ma ha come paradigmi speciali delle normative speciali che prevedono obblighi comportamentali nel corso del procedimento di formazione del contratto. Quindi le normative speciali in materia di consumatori in materia di pubblica amministrazione, in materia di contratti bancari, di contratti assicurativi, di contratti finanziari. Il filo conduttore di questa riflessione iniziale nella prima parte della lezione sarà l'espansione della responsabilità precontrattuale, perché la responsabilità precontrattuale è passata domiziana nel corso degli ultimi anni, da un modello basato sulla tipizzazione, cioè la responsabilità precontrattuale in presenza di determinati comportamenti tipizzati dalla legge millecentotrentotto o tipizzati dalla giurisprudenza. Passaggio da un modello tipizzate a un modello atipico basato sulla clausola generale sulla norma general, per cui le responsabilità precontrattuale non sono, nei casi tipizzati di scorrettezza nei casi di scorrettezza tipizzati dalla legge o dalla giurisprudenza che integra la legge, ma in tutte le ipotesi in cui vi sia un comportamento scorretto, produttivo ed un danno. Una lettura atipica che fa del tutto il paio con il carattere di clausola generale della buona fede che il canone che deve informare il comportamento precontrattuale. Questa atipicità ha diverse variabili e enunciamo rapidamente la prima e più importante atipicità e il superamento dell'idea che la responsabilità precontrattuale debba essere collegata alla trattativa fallita, alla trattativa fallita, cioè la trattativa che non culmina in modo positivo nel risultato atteso, cioè nella stipulazione di un contratto valido ed efficace. È fallita sia la trattativa quando il contratto non c'è il recesso ingiustificato dalle trattative, sia quando il contratto c'è, ma è come se non ci fosse perché è inefficace. Nulla improduttivo di effetti viene successivamente caducato questa tradizionale conformazione della responsabilità precontrattuale da trattativa fallita, in cui il bene giuridico leso e l'affidamento nella futura stipulazione del contratto si accompagna invece una responsabilità precontrattuale dal comportamento scorretto che produce un comportamento, o meglio che produce un contratto valido ma ingiusto, valido ma dannoso. Valido ma pregiudiziale. Quindi ipotesi in cui la trattativa non è fallita perché si è arrivati ad un contratto valido. Ma la trattativa è stata connotata da profili di ingiustizia, di abusivi, di approfittamento, di abuso che hanno condotto ad un contratto pregiudizievole. Ho comprato i beni, ma ad un prezzo superiore ho comprato un bene, ma con clausole dannose ho posto in essere un'operazione finanziaria che mi ha prodotto, una perdita contratto che non avrei stipulato, non con quel contenuto. Se non ci fosse stato un comportamento recettivo di inganno e di frode. Qui il bene leso non è l'interesse al contratto, perché quell'interesse è stato soddisfatto. Il bene leso è la libertà negoziale, cioè il diritto di autodeter
attuale da contatto sociale per violazione diciamo, della clausola generale della buona fede dei contatti sociali atipici ha senso quando la legge non specifichi con una norma apposita che c'è l'esistenza di un rapporto obbligatorio, cioè se c'è una norma come il milletrecentotrentasette, che modo puntuale giuridici una relazione sociale generica e la trasforma in rapporto obbligatorio in senso tecnico. Che bisogno c'è devi chiamare il contatto su ciò. Più che parlare di responsabilità da contatto sociale, che è una figura atipica a cui c'è bisogno di ricorrere, se non c'è una previsione legale, sarebbe più logico e sarebbe meno diciamo complicato parlare invece di una responsabilità contrattuale per inadempimento di un obbligo ex legge responsabilità contrattuale per inadempimento di un obbligo previsto puntualmente dalla legge e l'articolo milletrecentotrentasette che contrattualizza. Questo è un rapporto che lo trasforma da mero momento della vita di relazione generica in vera e propria forma di rapporto obbligatorio. Ed è quello che dice con molta chiarezza Mengoni, forse il giurista più puro dal punto di vista della sistematica e della dogmatica che, come ribadisco nel post ci ricorda che quando una norma giuridica assoggetta la relazione sociale all'imperativo della buona fede, trasforma questa relazione sociale in rapporto obbligatorio e quindi contrattualizza la relativa responsabilità. Quindi diciamo, um parlare di responsabilità contrattuale da contatto sociale per portare acqua al mulino di una teorica dalla dubbia, diciamo solidità è inutile, perché quando c'è una legge precisa che giuridici con la buona fede questa relazione è più logico parlare di responsabilità contrattuale da inadempimento di un obbligo previsto espressamente dalla legge. In ogni caso, di fronte a questa responsabilità precontrattuale senza contratto, e lo abbiamo ribadito nel posto e si pone il problema l'applicabilità di norme che il codice civile ha previsto immaginando la responsabilità contrattuale da contratto, qui invece abbiamo una responsabilità contrattuale senza contratto. Qual è la differenza? È che nel contratto le prestazioni sono determinate in modo puntuale e quindi sono prevedibili gli inadempimenti e soprattutto i pregiudizi. Invece nella responsabilità contrattuale senza contratto in cui l'obbligo violato non è un obbligo preciso previsto nel contratto, ma l'obbligo generale di buona fede. I comportamenti in adempitivi non sono tipizzati e i danni quindi non sono prevedibili. Per questo c'è il problema dell'applicabilità alla responsabilità contrattuale senza contratto del milleduecento diciotto, che esonera il debitore dalla prova dell'inadempimento sulla base dell'assunto che il comportamento del debitore è la causa più probabile dell'inadempimento e milleduecentoventicinque che limita il risarcimento al danno prevedibile se non c'è do c'è la base dell'assunto che al momento del contratto c'è una chiara programmazione e quindi possibilità di previsione. Queste due norme, secondo Giovanni Grasso, postulano entrambe la predeterminazione puntuale del contenuto dell'obbligazione e non sono quindi estensibili ad una responsabilità precontrattuale da violazione di una clausola generale e non da violazione di un obbligo comportamentale preciso. Ma quello che ci interessa di più torno Francesca alla domanda principale è la problematica della responsabilità precontrattuali da contratto valido ma sconveniente trovate nella dispensa una sentenza della Cassazione quattro sette uno cinque duemilaventidue che riprende alcuni precedenti. La prima è la sentenza marziale della Cassazione del duemilacinque, la seconda le sezioni unite ventiseimila settecentoventiquattro nel duemilasette e quindi la Cassazione, inserendosi in questa diciamo cornice. Agendo in questo ambito, percorrendo di nuovo questa strada, afferma che la responsabilità precontrattuale può derivare anche da contratto valido ma sconveniente, valido ma ingiusto, valido ma sperequato valido ma pregiudizievole. Divent
fitta di questa condizione di debolezza per imporre un regolamento iniquo, ma dove l'approfittamento non è necessariamente doloso, ma è anche un approfittamento dal comportamento contrario dal punto di vista oggettivo, pur senza animo s innocenti ad un parametro di correttezza. E insomma, secondo questa tesi che ci convince francamente la tutela della libertà negoziale non richiede solo la serietà, cioè la volontà di arrivare alla stipulazione del contratto richiede anche la lealtà, e cioè là volontà di arrivare a un contratto sulla base di una trattativa che consenta a entrambe le parti di autodeterminarsi in modo pienamente consapevole un contratto frutto di una trattativa giusta e quindi un contratto esso stesso giusto. Il criterio discreti, come dicono nella virgola due tra responsabilità contrattuale precontrattuale, non è quindi l'efficacia o la validità del contratto, quanto piuttosto la correttezza o meno del comportamento precedente alla stipula. Ora, voglio dire, qualcuno di voi ha dei dubbi su questa ricostruzione che è quella più coraggiosa e più innovativa? La responsabilità precontrattuale da contratto valido, frutto di una trattativa nel corso della quale ci sia stato oggettivamente un abuso di condizioni di inferiorità e quindi un abuso di vizi incompleti della volontà, quindi il comportamento sleale che conduce a un contratto di questo tipo? Qual è la perplessità che questa ricostruzione, che rende definitivamente atipica la responsabilità precontrattuale, può diciamo in generale che dici relazione che la le varie per sono valutazioni che riguardano la A ma di eh allora la prima obiezione che si muove, come dice un'ottima Elvira è la destabilizzazione della certezza dei rapporti giuridici, destabilizzazione dell'autonomia negoziale e soprattutto la destabilizzazione della regola della non interferenza tra norme di comportamento e norme di validità. Perché dice questa critica, in particolare il professor d'amico dell'università della calabria, nel nuovo tomo dell'enciclopedia del diritto dedicato al contratto si crea un vizio della volontà atipico. Si crea soprattutto una causa di invalidità atipica, quindi si incide sul numerous lalas delle cause di invalidità e soprattutto, come dice elvira, si consente al giudice di sindacare l'equilibrio contrattuale. È vero infatti che la pronuncia del giudice è una pronuncia di risarcimento, però di fatto si traduce in una nullità parziale. Cioè tu elimini, non la clausola che ha fissato un prezzo ingiusto, ma elimini gli effetti economici di quella clausola. E quindi, anche se dal punto di vista teorico il contratto rimane fermo, giudice vai nella sostanza a riscriverlo, a modificarne il contenuto economico, eliminando gli effetti economici delle clausole che hanno reso il contratto ingiusto e quindi c'è una sorta di pronuncia che sancisce una nullità parziale del contratto, una nullità atipica, così violando le regole in tema di numero chiuso e vizio della volontà di numero chiuso delle cause di invalidità e la regola generale della insindacabilità della dell'equilibrio contrattuale. Questa è la prima obiezione, diciamo è andare ad incidere su alcuni valori fondamentali del sistema la certezza l'autonomia, il numero chiuso delle cause di invalidità e soprattutto il principio di interferenza. E qui, sia pure sub specie di risarcimento, si va a riscrivere il contratto. La violazione di regola di condotta produce una riscrittura dell'atto finisce per essere una violazione di regola sull'atto. In ultima analisi, a questa prima obiezione se ne accompagna una seconda è che e più propriamente diciamo, legata alla coerenza sistematica. E si dice questo meccanismo di correzione del contenuto economico di un contratto valido finisce per essere profondamente contraddittorio, perché tu da un lato conosci che il contatto è valido dall'altro lato però in ultima analisi lo svuoti del suo contenuto e quindi c'è una profonda incoerenza in questa sorta di effetto anomalo che è ghigliottinare un contratto. Per quanto tu lo consideri valido ed efficace, è cont
novantotto, per non dire gli obblighi di informazione a favore del consumatore. Previsti molti contratti consumistici, come i contratti a distanza, come la multiproprietà, come i contratti relativi al turistico. Bene, quindi io credo che queste obiezioni possano essere superate. Quindi, ricapitolando, alla tesi della Cassazione della risarcibilità del danno precontrattuale da contratto valido ma sconveniente come reazione al contratto squilibrato, frutto di comportamento scorretto in un contesto asimmetrico caratterizzato da vizi incompleti della volontà, queste accuse si destabilizza. La certezza si crea un'invalidità atipica, si crea un vizio della volontà atipico. Si mette nel nulla il principio di non interferenza. Si consente un sindacato generalizzato sull'equilibrio contrattuale si scardina la coerenza del sistema. Si estendono analogicamente i casi tassativi in cui i contratti efficaci possono essere incisi sul piano degli effetti prodotti e si attribuisce una rilevanza anomala. All'errore sui motivi e a queste obiezioni sul piano milletrecentotrentasette è tipico sul piano astrologico. La buona fede è una clausola generale sul piano teologico. Lo scopo di protezione della norma vale anche per le condotte sleali che producono contratti ingiusti, non solo per le condotte superficiali che evitano la stipulazione del contratto finale, ma soprattutto sul piano sistematico. È importante ricordare questo non c'è una invalidità atipica, non c'è uno strumento atipico di correzione del contratto. Perché ci sarebbe invalidità atipica o strumento atipico di correzione del contratto se il giudice agisse sulla base della mera violazione di un precetto di giustizia obiettiva del contratto. Quindi accordarsi un danno per il solo fatto che il contratto è oggettivamente ingiusto, allora sarebbe certamente un'invalidità chiamata al risarcimento, perché andrebbe l' il risarcimento a reagire alla mera difformità del contratto rispetto a un paradigma di giustizia. Qui invece, ad essere violata è una regola comportamentale, tanto è vero che c'è bisogno che il comportamento sia colpevole, c'è bisogno che il comportamento sia dannoso e soprattutto c'è bisogno che il comportamento si inserisca all'interno di una trattativa asimmetrica. Sì da determinare una ingiustizia di carattere procedurale. Una Il rischio di accesso di tutela viene ad essere fronteggiato attraverso questo criterio di selezione della rilevanza, della alterazione della libertà negoziale, che deve essere una rilevanza significativa. A questo punto, diciamo, direi che la soluzione della Cassazione va salutata con favore, perché riprende la teoria dei vizi incompleti, nuovi, impropri, atipici della vizzi giri e chiarendo che millequattrocentoquaranta non è una norma eccezionale, ma è l'espressione di un principio per cui i vizi tipici producono invalidità, i vizi tipici tutti e il loro in incidente è solo un esempio. Producono un risarcimento del danno senza negare in modo radicale gli effetti contrattuali. Ora so che voi siete amanti di Rodolfo Sacco, soprattutto te, Sara. Quindi permettimi di ricordarti le parole di Rodolfo Sacco che con cui chiudo al primo post che dice c'è un rimedio del codice civile che potrebbe eliminare tutte le norme sull'errore sulla violenza e sul dolo senza modificare il contenuto di protezione del contraente che si trova a disagio a disagio. Questo è l'articolo milletrecentotrentasette. Come dire milletrecentotrentasette è una norma generale di protezione dei soggetti fragili. Quindi in fondo l'errore la violenza, non potrebbero essere cancellati e che basterebbe milletrecentotrentasette per concedere a colui che patisce un danno da scorrettezza procedimentale per effetto di un vizio della volontà per concedere una tutela riequilibratrice. Nella scorsa lezione da Giuseppe abbiamo d'altronde evidenziato che la differenza tra annullamento e nullità è tra l'altro rappresentata dal fatto che mentre la nullità è uno strumento di controllo sull'autonomia negoziale, l'annullamento è uno strumento di tutela dell'autonomia negoziale del soggetto, naturalmente più fragile, incapace, soggetto con la volontà viziata. E noi aggiungiamo oltre all'annullamento, anche il risarcimento del danno è uno strumento di protezione per i vizi atipici. Lo so, inizierei. Siamo in anticipo. La seconda parte della lezione sulla formazione del contratto. Questa volta come vorrei dire procedimento. Quindi le tecniche di formazione del contratto. Ora, Maria Elena, ti ricordi quante sono le procedure di formazione del contratto previste dalla legge? A occhio, Eh sì, sì. Senti, e da tutte queste belle cose, um, quale principio ricaviamo sulla formazione del contratto? Perché Mariana giustamente ricorda che il legislatore prevede dei modelli di formazione del contratto prevede il modello ordinario che immagina una società ottocentesca in cui si abita in luoghi diversi e si comunica ntes venga a sapere da una lettera di una proposta contrattuale inviatami dieci giorni prima rispondo a un'altra lettera con il contratto centese che si considera perfezionato quando il proponente ha notizia della accettazione dell'oblazione accettazione che quindi è un atto recettizio a parte della proposta. Il contratto si perfeziona quando c'è la acquisizione della notizia della accettazione. Questo modello legale ordinario. Poi abbiamo dei modelli leggeri, modelli leggeri, modelli di contratto semplificato di struttura esile. I contatti più facili e con cui si deroga a favore della semplicità rispetto a un modello eccessivamente complicato, eccessivamente asburgico e napoleonico come milletrecentoventisei sono quelli che ha citato elena milletrecentotrentatré il contratto con obbligazioni a carico del solo proponente si perfeziona, diciamo senza bisogno dell'accettazione espressa, diciamo così, salvo il potere di rifiuto. Poi c'è il milletrecentoventisette, un contratto che si perfeziona mediante l'esecuzione della prestazione da parte dell' oblato, senza che questa attività sia comunicata all'offerente. Poi abbiamo il milletrecentotrentadue, il contratto aperto l'adesione è un contratto aperto, sono tutti modelli semplificati che pongono problemi per nulla semplice milletrecentoventisette milletrecentotrentadue milletrecentotrentasette, poi abbiamo invece dei procedimenti aggravati, um procedimenti aggravati più pesanti, più diciamo, più duri, perché l'effetto giuridico di questi negozi è più importante e ha bisogno quindi di un procedimento al importante c'è bisogno di una proporzionalità tra il procedimento e l'effetto più l'effetto è significativo sacrificati rilevante, più il procedimento deve essere all'altezza del programma. Ciò accade per i contratti reali c'è bisogno della consegna dei contratti formali c'è bisogno della forma scritta milletrecentocinquanta del codice civile che secondo una tesi più rigorosa, deve essere presente sia nella proposta che nell'accettazione. I contratti della pubblica amministrazione sono aggravati sia dal punto di vista procedimentale c'è bisogno di un procedimento ad evidenza pubblica per scegliere il contraente, per stabilire il contenuto del contratto, ma anche dal punto di vista formale, perché l'articolo diciotto del nuovo codice ha ribadito ciò che già era scritto nella contabilità di stato del ventitré i contratti della p a hanno forma scritta, devono avere per forza forma scritta, quindi forma pubblica notarile, forma pubblica amministrativa e, in taluni casi, scrittura privata. In altri casi sono aggravati i contratti tra professionista e consumatore. Quante volte la legge richiede una procedura specifica e una f ad hoc, a tutela e a protezione del consumatore. Altri contratti, invece hanno una procedura. Vorrei dire invece né aggravata né semplificata, ma semplicemente differente rispetto a quella ordinaria. Una differenza che mira ad adattare la procedura ordinaria alla peculiarità della stipulazione medesima. Questo vale per i contratti telematici. Dove si il problema di raccordare l'incontro proposte, accettaz
ra sottoscrizione contestuale del documento. Accordi verbali istantanei come quelli del supermercato no quelle procedure completamente atipiche oppure introdurre deroghe alle procedure tipiche. Ad esempio nella procedura tipica del contratto centese l'accettazione è recettizi, quindi produce effetti solo quando viene riconosciuta la proponente. Ma perché il proponente non dovrebbe poter rinunciare alla recettizi dell'accettazione? Io ti faccio la proposta e ritengo il contratto formato quando tu l'accetti ancor prima della mia conoscenza dell'accettazione d'altronde la conoscenza è nel mio interesse. Se io rinuncio tanto meglio per la controparte no rinuncia alla ricettività dell'accettazione o al contrario, una deroga aggrava nel milletrecentotrentatré quando il contratto con l'obbligazione a carico del solo proponente l'accettazione non deve essere espressa. Ma nulla esclude che il proponente di un contratto di questo tipo dica pa, io la la voglio espressa l'accettazione io propongo io do le carte, io ti propongo un contratto e ti chiedo di accettare in modo espresso altrimenti il contratto per me non sarà concluso come nel milletrecentoventisette e il contratto si perfeziona quando viene iniziata l'esecuzione della prestazione. Ma il proponente potrebbe dire per me si perfeziona quando la ottengo io la prestazione quando me ne approprio non basta che tu la segui, ma io devo ottenere materialmente diciamo appropriarmi materialmente della tua prestazione come d'altronde pacifico che il proponente possa porre all' oblato di sull'accettazione di qualsiasi tipo vincoli linguistici accetta in turco io considero accettato e conta solo se tu lo accetterai in una certa lingua. Vincoli temporali deve accettare entro un certo arco di tempo vincoli formali deve accettare in una forma precisa di un certo tipo d'altro sono vincoli che l'ob- può accettare o non accettare, quindi non c'è alcuna lesione della sua libertà negoziale. Diverso sarebbe se il proponente dicesse come dico nel punto diciamo è del post se dicesse guarda, io ti faccio questa proposta e la considero accettata se tu non la rifiuti entro dieci giorni beh, tu impone un obbligo comportamentale e quindi limiti la libertà. La principale libertà dell'uomo è la libertà di non far nulla è la cosiddetta tutela dell'inerzia. Per questo io con la proposta impongo all' oblato un comportamento positivo di rifiuto per evitare l'accettazione io inc- sulla sua libertà negoziale obbligo ad un comportamento positivo per evitare la stipulazione, mentre invece se linguistici te impara formali puoi non far nulla e quindi la proposta cade nel nulla. Appunto. Quindi sono possibili proc completamente tipiche. Sono possibili deroghe alle procedure tipiche. Sono possibili in terzo luogo, contratti normativi che fissino regole procedurali o regole formali per il milletrecentocinquantadue, un contratto che fissa la forma del futuro contratto. È un contratto che fissa la norma del futuro contratto. Certamente è possibile fissare vincoli di altro tipo in un contratto che, detti le regole su un futuro contratto. Sono possibili in qualche luogo vincoli posti da negozi precontrattuali limitativi della libertà negoziale, che fissano cioè vincoli in fu in vista del futuro contratto. Pensate alla prelazione. Beh, la prelazione non è prevista dalla legge. La prelazione convenzionale atipica può essere fissata da un accordo con cui una parte si impegna a preferire Beatrice se se se deciderà di vendere un certo bene, è un vincolo limitativo per la libertà negoziale. Come d'altronde, non credo che possano esserci dubbi la possibilità di introdurre alternative consensuali ai contratti reali o alternative reali e contatti consensuali. Il mutuo è reale, ma non penso che possa essere considerato illegittimo un mutuo consensuale. La locazione è un contratto consensuale, ma non penso che sia impedita una locazione reale con cui si stabilisca che il contratto si perfeziona al momento della consegna della resa. Quindi e arriviamo alla