# %% [markdown]
# # Example
# this file show the process of RAG for a speech-to-text uses case
#
# in this notebook:
#
# 1. **Speech-to-text (STT)**: we perform STT on a iven audio file, using a Whisper open-source model
#
# 2. *Chunking*: we take the extracted text, we create a **Langchain Document** from it, then we split the document into **chunks** using the spacy library.
#
# 3. **Summarization**: we take the chunks and summarize them into a single big summary using **map reduce** approach: see https://python.langchain.com/docs/use_cases/summarization
#
# 4. **Embedding and store**: we create **embeddings** of the summary and then store the embeddins on **Qdrant DB**
#
# Note: this approach will be used for all of our use cases, not only for Speech-to-text!

# %%
import whisper
import sys
sys.path.append('..')
from utils import AWSTexttract, TextSplitter, LangChainAI, QDrantDBManager, EmbeddingFunction
import pytube
model = whisper.load_model("base")
import os

# %% [markdown]
# # 1. Speech-to-text
# Im using Whisper model her ebut feel free to use other open source models if you want

# %%
# model = whisper.load_model("large")
model = whisper.load_model("base")

# %%
filename=r"C:\Users\ELAFACRB1\Downloads\AUD-20240319-WA0006.m4a" #put your file here 
text = model.transcribe(filename)
text['text']
# Out:
# c:\Users\ELAFACRB1\venvs\langchain\Lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# " Ciao ragazzi buongiorno. Buongiorno a tutti. Si sente bene, però anche dietro si sente. Allora ragazzi un paio di avvisimo, nevo farvi. Per quanto riguarda il mese di marzo di affile, troverete quando pubblica in un paio di appuntamenti in più, di approfondimenti, oltre le canoniche, lezioni che pensate. E saranno due approfondimenti due focos, uno di penale e uno in materia di civile. Uno sarà registrato, quindi veloca richeremo nei cruxcotti e rimarrà vostra disposizione da parte della proessore ssamorello. E poi l'altro invece sarà indiretta un paio di ore su piattaforma zoom con l'avvocato del lo stato in manu e le manzo. Invece per quanto riguarda l'altra novità è che da questo l'unedice, da l'unedì prossimo, torna l'appuntamento ogni l'unedì diciamo di fine mese. Per gli approfondimenti con il presidente, sempre su piattaforma zoom ovviamente, gli approfondimenti su tutte le questioni di rilievo ovviamente che avete trattato nel mese appena concluso. Quindi magari il presidente è stesso vi forra delle domande preventivamente sullo gruppo Facebook, sulle quale possiamo scegliare i flette e soprattutto voi farete, porrete le domande, il mio consiglio il consiglio è di porre, l'altrettante domande è sempre su Facebook così lui sa già di che cosa su quali argomenti dovranno andare a battere, ma soprattutto voi saprete già più o meno di cosa si parlerà, quindi vi è arrivato a vedere qualche argomento, piuttosto che gli appunti piuttosto che la dispensa giurispevenziale. E quindi questo approfondimento sempre alle V8 sarà più o meno su piattaforma zoom, dovrete link come al solito sull' vostro cruzcotto una mattina della sessione di 1,5-2, io penso un'area, un'oreta, neanche un paio, un'oreta, e sarà una approfondita molto molto prezioso perché magari finita le azioni che vi è tutto chiaro, però poi magari studiando, e la andandova a approfondire iniziano a venire i dubbi, e quindi avrete la possibilità di porri, ma soprattutto di sciogliati. Grazie mille, grazie mille. Grazie a me, devo dire domenico che questo poste lo rendro a V8 perché trovo una classe molto diminua quest'anno, cioè rispetto ai vostri homologi, rispetto alla Aussiti e prima maniera, diciamo così, e in prima repubblica. I naufiti di quest'anno sono moccissimi, non fanno domani, stanno dietro, c'è una sfonda, non intervengono Facebook e diventato un cimitero in cui parlo da solo, senza avere risposte che è l'antichamera. Della po' di è questo molto male, io dico, la contervista di BAT, diciamo di datico, quindi sia quando un pubblico le pillo le rimanendo totalmente in ascontato, tanto che mi pongo le problemi, ma arrivano o no, sia quando, diciamo, quando studiate la lezione fate domande intervenite, fate queste lezione e questo poste lezione che faremo ogni lunedì di fine mesi, quindi a partire dal prossimo, alle 18, servirà a stimolare i cadavere che sono in voi, quindi affronteremo tutte le questioni problemati che delle lezione del mese, questo caso la bulk, stanno le sproprezioni sanante, l'annurità del contato, il preliminare è tutto il resto, dire che potrebbe sottopotulo che prima di lunedì tutti voi, al traverso Facebook inviasse le domande e quindi anticipaste quale la tematica con le siono-planme di tematici è vinteressano, detto ciò se vietro l'autorizzazione, io inizierai, la lezione non senza aver salutato il mio nuovo amico di un sempre che ordinario, che pensate un po', il paio con l'aria che viene dalla calabria ingionata ed è, diciamo, un eroica, consista, invece più se è pebbene, da bar, se no, bar ese è un viaggiatore mercante e tendenzialmente uno spredgiulicato, quindi c'è sta che venga ingionata, da bar, però il suo guagio è che figlio di due colleghi di cui Paola, la mamma, è stata una mia lieva, il baban, non è su un sicuro ma mi fa piacere pensare che anche l'urosea è stato, non è certo, però è bello pensare che sia così e l'uja è una grande responsabilità, che fa di concorsi magistratura, se non fiduo di un magistrato e difficil ...

# %% [markdown]
# # 2. Chunking

# %%
text_summarizer = TextSplitter(chunk_size=16000, chunk_overlap=0)

# %% [markdown]
# Text splitting

# %%
#this function uses semantic text splitting using spacy 
#other functions uses 
splitted_text = text_summarizer.semantic_split_text(text['text']) 
len(splitted_text)
# Out:
# 26

# %% [markdown]
# Creation of Langchain documents

# %%
docs =  text_summarizer.create_langchain_documents(splitted_text, {"source": "mp3"})
len(docs)
# Out:
# 26

# %% [markdown]
# # 3. Summarization

# %%
langchain_client = LangChainAI()
summary=langchain_client.summarize_text(docs)
# Out:
# c:\Users\ELAFACRB1\venvs\langchain\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %% [markdown]
# # 4. Embedding and store

# %% [markdown]
# Indexing on Qdrant vector database

# %%
QDRANT_URL=os.getenv('QDRANT_URL')
COLLECTION_NAME=os.getenv('COLLECTION_NAME')

#here Im using the EmbeddingFunction class to instantiate an embedding model 
#(openai in this case, feel free to test other embedding functions in the future)

#as a record manager (database used to store hash of the embedded documents used to avoid storing the 
#same document twice) I'm using a local sql database, we can use other db in the future

qdrantClient = QDrantDBManager(
    url=QDRANT_URL,
    port=6333,
    collection_name=COLLECTION_NAME,
    vector_size=1536,
    embedding=EmbeddingFunction('openAI').embedder,
    record_manager_url="sqlite:///record_manager_cache.sql"
)
qdrantClient.index_documents(docs)
